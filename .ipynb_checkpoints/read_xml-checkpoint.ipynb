# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_xml("students.xml")

# %%
df
# Out:
#     id     name  age  height grade degree institute    country      gender
# 0    1    Alice   23  200 cm     F    MSc   Caltech  Singapore        Male
# 1    2  Charlie   18  164 cm     B    MBA       MIT  Singapore  Non-binary
# 2    3   Hannah   26  151 cm     A    PhD       NUS     Canada  Non-binary
# 3    4    Alice   25  188 cm     C    PhD   Harvard      India  Non-binary
# 4    5   Edward   21  198 cm     B    PhD       IIT      India      Female
# 5    6  Charlie   22  160 cm     D    PhD   Harvard  Singapore  Non-binary
# 6    7    Alice   27  152 cm     D    MSc       IIT        USA        Male
# 7    8    Alice   30  162 cm     C    MBA  Stanford         UK  Non-binary
# 8    9   Edward   25  151 cm     E    BSc  Stanford     Canada        Male
# 9   10      Ian   22  198 cm     C     BA   Caltech    Germany      Female
# 10  11      Ian   18  174 cm     E    PhD   Caltech        USA      Female
# ...

# %%
df.to_xml("df.xml")
