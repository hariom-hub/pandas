# %%
import numpy as np
from io import StringIO
import pandas as pd

# %%
urlfile = pd.read_csv('cu.item',sep = '\t',engine='python')

# %%
urlfile
# Out:
#     item_code                                          item_name  \
# 0         AA0                               All items - old base
# 1        AA0R  Purchasing power of the consumer dollar - old ...
# 2         SA0                                          All items
# 3        SA0E                                             Energy
# 4       SA0L1                                All items less food
# ..        ...                                                ...
# 395   SSEA011                                  College textbooks
# 396   SSEE041                                        Smartphones
# 397  SSFV031A           Food at elementary and secondary schools
# 398   SSGE013                                 Infants' equipment
# 399   SSHJ031                                 Infants' furniture
#
#      display_level selectable  sort_sequence
# 0                0          T              2
# 1                0          T            400
# 2                0          T              1
# ...

# %%
type(urlfile)
# Out:
# pandas.core.frame.DataFrame

# %%
urlfile
# Out:
#     item_code                                          item_name  \
# 0         AA0                               All items - old base
# 1        AA0R  Purchasing power of the consumer dollar - old ...
# 2         SA0                                          All items
# 3        SA0E                                             Energy
# 4       SA0L1                                All items less food
# ..        ...                                                ...
# 395   SSEA011                                  College textbooks
# 396   SSEE041                                        Smartphones
# 397  SSFV031A           Food at elementary and secondary schools
# 398   SSGE013                                 Infants' equipment
# 399   SSHJ031                                 Infants' furniture
#
#      display_level selectable  sort_sequence
# 0                0          T              2
# 1                0          T            400
# 2                0          T              1
# ...

# %%
urlfile.iloc[0:41]
# Out:
#    item_code                                          item_name  \
# 0        AA0                               All items - old base
# 1       AA0R  Purchasing power of the consumer dollar - old ...
# 2        SA0                                          All items
# 3       SA0E                                             Energy
# 4      SA0L1                                All items less food
# 5     SA0L12                    All items less food and shelter
# 6    SA0L12E           All items less food, shelter, and energy
# 7   SA0L12E4  All items less food, shelter, energy, and used...
# 8     SA0L1E                     All items less food and energy
# 9      SA0L2                             All items less shelter
# 10     SA0L5                        All items less medical care
# 11     SA0LE                              All items less energy
# 12      SA0R            Purchasing power of the consumer dollar
# 13     SA311                              Apparel less footwear
# ...

# %%
urlfile
# Out:
#     item_code                                          item_name  \
# 0         AA0                               All items - old base
# 1        AA0R  Purchasing power of the consumer dollar - old ...
# 2         SA0                                          All items
# 3        SA0E                                             Energy
# 4       SA0L1                                All items less food
# ..        ...                                                ...
# 395   SSEA011                                  College textbooks
# 396   SSEE041                                        Smartphones
# 397  SSFV031A           Food at elementary and secondary schools
# 398   SSGE013                                 Infants' equipment
# 399   SSHJ031                                 Infants' furniture
#
#      display_level selectable  sort_sequence
# 0                0          T              2
# 1                0          T            400
# 2                0          T              1
# ...

# %%
csvfile = urlfile.to_csv()

# %%
urlfile
# Out:
#     item_code                                          item_name  \
# 0         AA0                               All items - old base
# 1        AA0R  Purchasing power of the consumer dollar - old ...
# 2         SA0                                          All items
# 3        SA0E                                             Energy
# 4       SA0L1                                All items less food
# ..        ...                                                ...
# 395   SSEA011                                  College textbooks
# 396   SSEE041                                        Smartphones
# 397  SSFV031A           Food at elementary and secondary schools
# 398   SSGE013                                 Infants' equipment
# 399   SSHJ031                                 Infants' furniture
#
#      display_level selectable  sort_sequence
# 0                0          T              2
# 1                0          T            400
# 2                0          T              1
# ...

# %%
urlfile.to_csv()
# Out:
# ',item_code,item_name,display_level,selectable,sort_sequence\r\n0,AA0,All items - old base,0,T,2\r\n1,AA0R,Purchasing power of the consumer dollar - old base,0,T,400\r\n2,SA0,All items,0,T,1\r\n3,SA0E,Energy,1,T,375\r\n4,SA0L1,All items less food,1,T,359\r\n5,SA0L12,All items less food and shelter,1,T,362\r\n6,SA0L12E,"All items less food, shelter, and energy",1,T,363\r\n7,SA0L12E4,"All items less food, shelter, energy, and used cars and trucks",1,T,364\r\n8,SA0L1E,All items less food and energy,1,T,360\r\n9,SA0L2,All items less shelter,1,T,361\r\n10,SA0L5,All items less medical care,1,T,357\r\n11,SA0LE,All items less energy,1,T,358\r\n12,SA0R,Purchasing power of the consumer dollar,0,T,399\r\n13,SA311,Apparel less footwear,1,T,365\r\n14,SAA,Apparel,0,T,187\r\n15,SAA1,Men\'s and boys\' apparel,1,T,188\r\n16,SAA2,Women\'s and girls\' apparel,1,T,195\r\n17,SAC,Commodities,1,T,366\r\n18,SACE,Energy commodities,1,T,376\r\n19,SACL1,Commodities less food,1,T,367\r\n20,SACL11,Commodities le
# ...
