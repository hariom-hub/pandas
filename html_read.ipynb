# %%
import numpy as np
import pandas as pd
from io import StringIO

# %%
html = pd.read_html("https://en.wikipedia.org/wiki/Mobile_country_code")

# %%
html
# Out:
# [   MCC  MNC Brand      Operator       Status Bands (MHz)  \
#  0    1    1  TEST  Test network  Operational         any
#  1    1    1  TEST  Test network  Operational         any
#  2  999   99   NaN  Internal use  Operational         any
#  3  999  999   NaN  Internal use  Operational         any
#
#                                References and notes
#  0                                              NaN
#  1                                              NaN
#  2  Internal use in private networks, no roaming[6]
#  3  Internal use in private networks, no roaming[6]  ,
#       Mobile country code                                    Country ISO 3166  \
#  0                    289                                 A Abkhazia    GE-AB
#  1                    412                                Afghanistan       AF
#  2                    276                                    Albania       AL
#  3                    603                                    Algeria       DZ
# ...

# %%
type(html)
# Out:
# list

# %%
html[0]
# Out:
#    MCC  MNC Brand      Operator       Status Bands (MHz)  \
# 0    1    1  TEST  Test network  Operational         any
# 1    1    1  TEST  Test network  Operational         any
# 2  999   99   NaN  Internal use  Operational         any
# 3  999  999   NaN  Internal use  Operational         any
#
#                               References and notes
# 0                                              NaN
# 1                                              NaN
# 2  Internal use in private networks, no roaming[6]
# 3  Internal use in private networks, no roaming[6]

# %%
html[1]
# Out:
#      Mobile country code                                    Country ISO 3166  \
# 0                    289                                 A Abkhazia    GE-AB
# 1                    412                                Afghanistan       AF
# 2                    276                                    Albania       AL
# 3                    603                                    Algeria       DZ
# 4                    544  American Samoa (United States of America)       AS
# ..                   ...                                        ...      ...
# 247                  452                                    Vietnam       VN
# 248                  543                        W Wallis and Futuna       WF
# 249                  421                                    Y Yemen       YE
# 250                  645                                   Z Zambia       ZM
# 251                  648                                   Zimbabwe       ZW
#
# ...

# %%
# now if we want to choose the table from a webpage specifically then we will use the "match" parameter which will be equal to some keyword like a heading, name, property and etc.

html1 = pd.read_html("https://en.wikipedia.org/wiki/List_of_largest_companies_by_revenue",match="Rank")

# %%
type(html1)
# Out:
# list

# %%
html1[0]
# Out:
#    Rank                                      Ram  \
#    Rank                                      Ram
# 0     1                                  Walmart
# 1     2                                   Amazon
# 2     3          State Grid Corporation of China
# 3     4                             Saudi Aramco
# 4     5          China Petrochemical Corporation
# 5     6     China National Petroleum Corporation
# 6     7                                    Vitol
# 7     8                                    Apple
# 8     9                       UnitedHealth Group
# 9    10                       Berkshire Hathaway
# 10   11                               CVS Health
# 11   12                         Volkswagen Group
# 12   13                               ExxonMobil
# 13   14                                    Shell
# 14   15     China State Construction Engineering
# 15   16                                   Toyota
# 16   17                                 McKesson
# ...

# %%
html3 = pd.read_html("https://en.wikipedia.org/wiki/QS_World_University_Rankings",match="Categories of QS World University Rankings by Faculty and Subject")

# %%
html3[0]
print(type(html3[0]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
html3[0]
# Out:
#                   Arts & Humanities  Engineering & Technology  \
# 0                      Art & Design          Computer Science
# 1                      Architecture              Data Science
# 2                       Archaeology    Engineering – Chemical
# 3                          Classics       Engineering – Civil
# 4   English Language and Literature  Engineering – Electrical
# 5                           History  Engineering – Mechanical
# 6                   Performing Arts     Engineering – Mineral
# 7                    History of Art     Petroleum Engineering
# 8                       Linguistics                       NaN
# 9                  Modern Languages                       NaN
# 10                       Philosophy                       NaN
# 11                         Theology                       NaN
# 12                              NaN                       NaN
# 13                              NaN                       NaN
# ...

# %%
html3
# Out:
# [                  Arts & Humanities  Engineering & Technology  \
#  0                      Art & Design          Computer Science
#  1                      Architecture              Data Science
#  2                       Archaeology    Engineering – Chemical
#  3                          Classics       Engineering – Civil
#  4   English Language and Literature  Engineering – Electrical
#  5                           History  Engineering – Mechanical
#  6                   Performing Arts     Engineering – Mineral
#  7                    History of Art     Petroleum Engineering
#  8                       Linguistics                       NaN
#  9                  Modern Languages                       NaN
#  10                       Philosophy                       NaN
#  11                         Theology                       NaN
#  12                              NaN                       NaN
#  13                              NaN                       NaN
# ...

# %%
html3[0]
# Out:
#                   Arts & Humanities  Engineering & Technology  \
# 0                      Art & Design          Computer Science
# 1                      Architecture              Data Science
# 2                       Archaeology    Engineering – Chemical
# 3                          Classics       Engineering – Civil
# 4   English Language and Literature  Engineering – Electrical
# 5                           History  Engineering – Mechanical
# 6                   Performing Arts     Engineering – Mineral
# 7                    History of Art     Petroleum Engineering
# 8                       Linguistics                       NaN
# 9                  Modern Languages                       NaN
# 10                       Philosophy                       NaN
# 11                         Theology                       NaN
# 12                              NaN                       NaN
# 13                              NaN                       NaN
# ...

# %%
html3[0].to_html("table.html")
